# %%
import pandas as pd
import numpy as np
import datetime as dt
import yfinance as yf
import matplotlib.pyplot as plt

# %%
end = dt.datetime.today()
start = end - dt.timedelta(days=50*365)
data = yf.download('^GSPC', start=start, end=end, progress=True, interval='1mo')
# Out:
# [*********************100%***********************]  1 of 1 completed

# %%
data
# Out:
# Price             Close         High          Low         Open        Volume
# Ticker            ^GSPC        ^GSPC        ^GSPC        ^GSPC         ^GSPC
# Date
# 1985-01-01   179.630005   180.270004   163.360001   167.199997    2673710000
# 1985-02-01   181.179993   183.949997   177.750000   179.630005    2194620000
# 1985-03-01   180.660004   183.889999   176.529999   181.179993    2153090000
# 1985-04-01   179.830002   183.610001   177.860001   180.660004    1981880000
# 1985-05-01   189.550003   189.979996   178.350006   179.830002    2350340000
# ...                 ...          ...          ...          ...           ...
# 2026-02-01  6878.879883  6993.479980  6775.500000  6916.640137  113685560000
# 2026-03-01  6528.520020  6901.009766  6316.910156  6824.359863  129104600000
# 2026-04-01  7209.009766  7219.830078  6474.939941  6556.560059  105654650000
# 2026-05-01  7580.060059  7599.379883  7174.120117  7234.540039  112555780000
# ...
